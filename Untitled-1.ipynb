# %%
pip install pandas openpyxl xlrd
# Out:
# Requirement already satisfied: pandas in c:\users\jtwpi\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: openpyxl in c:\users\jtwpi\anaconda3\lib\site-packages (3.1.5)
# Requirement already satisfied: xlrd in c:\users\jtwpi\anaconda3\lib\site-packages (2.0.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\jtwpi\anaconda3\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jtwpi\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jtwpi\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jtwpi\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in c:\users\jtwpi\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\jtwpi\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.read_excel("mobiliteitsdata.xlsx", engine="openpyxl")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_excel("mobiliteitsdata.xlsx", engine="openpyxl")
#
# File c:\Users\jtwpi\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File c:\Users\jtwpi\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:1567, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1564 self.engine = engine
#    1565 self.storage_options = storage_options
# -> 1567 self._reader = self._engines[engine](
#    1568     self._io,
#    1569     storage_options=storage_options,
#    1570     engine_kwargs=engine_kwargs,
#    1571 )
#
# File c:\Users\jtwpi\anaconda3\Lib\site-packages\pandas\io\excel\_openpyxl.py:553, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     541 """
#     542 Reader using openpyxl engine.
#     543
#    (...)
#     550     Arbitrary keyword arguments passed to excel engine.
#     551 """
#     552 import_optional_dependency("openpyxl")
# --> 553 super().__init__(
#     554     filepath_or_buffer,
#     555     storage_options=storage_options,
#     556     engine_kwargs=engine_kwargs,
#     557 )
#
# File c:\Users\jtwpi\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:563, in BaseExcelReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     559 self.handles = IOHandles(
#     560     handle=filepath_or_buffer, compression={"method": None}
#     561 )
#     562 if not isinstance(filepath_or_buffer, (ExcelFile, self._workbook_class)):
# --> 563     self.handles = get_handle(
#     564         filepath_or_buffer, "rb", storage_options=storage_options, is_text=False
#     565     )
#     567 if isinstance(self.handles.handle, self._workbook_class):
#     568     self.book = self.handles.handle
#
# File c:\Users\jtwpi\anaconda3\Lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mobiliteitsdata.xlsx'

# %%
df.describe()
# Out:
#           persoon_ID     leeftijd  gewicht_KG  jaarsalaris_eu  \
# count    1500.000000  1500.000000  1500.00000     1499.000000
# mean   560229.090000    47.989333    75.14630    40092.551094
# std    260939.294996    18.134915    14.79674    14986.839768
# min    102295.000000     0.000000     0.00000    -8505.150000
# 25%    332525.750000    32.000000    65.63500    30008.920000
# 50%    563847.000000    47.000000    75.79000    40503.080000
# 75%    792686.750000    64.000000    84.93500    50281.165000
# max    999493.000000    79.000000   117.76000    93826.850000
#
#        huishouden_grootte  km_auto_per_jaar  km_fiets_per_jaar  \
# count         1500.000000       1500.000000        1500.000000
# mean             3.032000       8597.262393        1794.180353
# std              1.411017       7021.428530         753.991154
# min              1.000000      -6506.630000           0.000000
# 25%              2.000000          0.000000        1503.420000
# 50%              3.000000       9356.380000        1910.005000
# 75%              4.000000      13842.732500        2286.180000
# max              5.000000      34618.870000        3672.700000
#
#        km_ov_per_jaar  km_vliegtuig_per_jaar  \
# count     1500.000000            1500.000000
# mean      2942.222840            1072.277327
# std       1531.377214             748.651072
# min      -2264.780000               0.000000
# 25%       1950.682500             471.540000
# 50%       2987.030000            1052.140000
# 75%       3991.537500            1588.555000
# max       8018.060000            3808.200000
#
#        dagen_thuiswerken_per_week_pro_rato  \
# count                          1500.000000
# mean                              2.532667
# std                               1.671365
# min                               0.000000
# 25%                               1.000000
# 50%                               3.000000
# 75%                               4.000000
# max                               5.000000
#
#        dagen_kantoorwerken_per_week_pro_rato  dagen_in_buitenland_per_jaar  \
# count                            1500.000000                   1500.000000
# mean                                2.467333                     14.485333
# std                                 1.671365                      8.700819
# min                                 0.000000                      0.000000
# 25%                                 1.000000                      7.000000
# 50%                                 2.000000                     15.000000
# 75%                                 4.000000                     22.000000
# max                                 5.000000                     29.000000
#
#        co2_uitstoot_per_jaar_KG
# count               1493.000000
# mean                4912.341875
# std                 3422.902397
# min                    0.000000
# 25%                 1469.450000
# 50%                 4677.280000
# 75%                 7481.550000
# max                18098.440000

# %%
for kolom in df.select_dtypes(include='number').columns:
    aantal_negatief = (df[kolom] < 0).sum()
    if aantal_negatief > 0:
        print(f"{kolom}: {aantal_negatief} negatieve waarden")
# Out:
# jaarsalaris_eu: 7 negatieve waarden
# km_auto_per_jaar: 12 negatieve waarden
# km_ov_per_jaar: 41 negatieve waarden

# %%
new_df = df[
    (df['jaarsalaris_eu'] >= 0) &
    (df['km_auto_per_jaar'] >= 0) &
    (df['km_ov_per_jaar'] >= 0)
]
new_df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 new_df = df[
#       2     (df['jaarsalaris_eu'] >= 0) &
#       3     (df['km_auto_per_jaar'] >= 0) &
#       4     (df['km_ov_per_jaar'] >= 0)
#       5 ]
#       6 new_df.shape
#
# NameError: name 'df' is not defined
